# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4e462d0603aa631588b3bcd178ae4e81

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | padang
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | kiunga
# Processing Record 5 of Set 1 | kearney
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | san bartolome de tirajana
# Processing Record 8 of Set 1 | vallenar
# Processing Record 9 of Set 1 | constantine
# Processing Record 10 of Set 1 | hervey bay
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | rio branco do sul
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | sinnamary
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | narayanganj
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | dossor
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | rapid valley
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | konstantinovka
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | santa lucia
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 1 | faya
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | yzeure
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | lavrentiya
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | mpulungu
# Processing Record 39 of Set 1 | severo-yeniseyskiy
# Processing Record 40 of Set 1 | mount isa
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 1 | yulara
# Processing Record 44 of Set 1 | yar-sale
# Processing Record 45 of Set 1 | port-gentil
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | constitucion
# Processing Record 49 of Set 1 | bambanglipuro
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | wasilla
# Processing Record 3 of Set 2 | genhe
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | cochrane
# Processing Record 6 of Set 2 | half moon bay
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | bandiagara
# Processing Record 9 of Set 2 | vao
# Processing Record 10 of Set 2 | astana
# Processing Record 11 of Set 2 | kavieng
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | alekseyevsk
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 2 | pokhara
# Processing Record 20 of Set 2 | horsham
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | fukue
# Processing Record 23 of Set 2 | saint-augustin
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | cabo san lucas
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | panjab
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | nemuro
# Processing Record 30 of Set 2 | port lincoln
# Processing Record 31 of Set 2 | alofi
# Processing Record 32 of Set 2 | polis
# Processing Record 33 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 2 | misasi
# Processing Record 35 of Set 2 | mingguang
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | sambava
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | sola
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | haines junction
# Processing Record 44 of Set 2 | luanda
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | huaicheng
# Processing Record 48 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | disna
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | lodwar
# Processing Record 3 of Set 3 | beloha
# Processing Record 4 of Set 3 | poum
# Processing Record 5 of Set 3 | fairlie
# Processing Record 6 of Set 3 | edd
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | riyadh
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | caborca
# Processing Record 16 of Set 3 | altay
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 3 | acapulco
# Processing Record 20 of Set 3 | atambua
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 | brae
# Processing Record 23 of Set 3 | ternate
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | nenjiang
# Processing Record 26 of Set 3 | safford
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | richards bay
# Processing Record 29 of Set 3 | jinchang
# Processing Record 30 of Set 3 | talawdi
# City not found. Skipping...
# Processing Record 31 of Set 3 | bubaque
# Processing Record 32 of Set 3 | umm kaddadah
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | san clemente
# Processing Record 38 of Set 3 | aksu
# Processing Record 39 of Set 3 | litovko
# Processing Record 40 of Set 3 | wejherowo
# Processing Record 41 of Set 3 | avera
# Processing Record 42 of Set 3 | grand forks
# Processing Record 43 of Set 3 | raton
# Processing Record 44 of Set 3 | mount gambier
# Processing Record 45 of Set 3 | krasnoarmeysk
# Processing Record 46 of Set 3 | aasiaat
# Processing Record 47 of Set 3 | almonte
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | rafaela
# Processing Record 50 of Set 3 | smithers
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | portland
# Processing Record 4 of Set 4 | merauke
# Processing Record 5 of Set 4 | magadan
# Processing Record 6 of Set 4 | huarmey
# Processing Record 7 of Set 4 | holme
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | deshnok
# Processing Record 10 of Set 4 | zlobin
# Processing Record 11 of Set 4 | cobija
# Processing Record 12 of Set 4 | te anau
# Processing Record 13 of Set 4 | yerbogachen
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | gat
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | berlevag
# Processing Record 24 of Set 4 | bolu
# Processing Record 25 of Set 4 | harper
# Processing Record 26 of Set 4 | ternovka
# Processing Record 27 of Set 4 | terrace
# Processing Record 28 of Set 4 | bilibino
# Processing Record 29 of Set 4 | malakal
# Processing Record 30 of Set 4 | sechura
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | mabaruma
# Processing Record 33 of Set 4 | chernyshevsk
# Processing Record 34 of Set 4 | bonavista
# Processing Record 35 of Set 4 | khatra
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | auki
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | porbandar
# Processing Record 41 of Set 4 | pedernales
# Processing Record 42 of Set 4 | bandarbeyla
# Processing Record 43 of Set 4 | monrovia
# Processing Record 44 of Set 4 | thinadhoo
# Processing Record 45 of Set 4 | havoysund
# Processing Record 46 of Set 4 | abu dhabi
# Processing Record 47 of Set 4 | nanortalik
# Processing Record 48 of Set 4 | onega
# Processing Record 49 of Set 4 | flin flon
# Processing Record 50 of Set 4 | clarksville
# Processing Record 1 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 5 | cozumel
# Processing Record 3 of Set 5 | cerchezu
# Processing Record 4 of Set 5 | sungaipenuh
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | los llanos de aridane
# Processing Record 7 of Set 5 | amapa
# Processing Record 8 of Set 5 | muzhi
# Processing Record 9 of Set 5 | wilmington
# Processing Record 10 of Set 5 | camacha
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | misratah
# Processing Record 13 of Set 5 | ayer itam
# City not found. Skipping...
# Processing Record 14 of Set 5 | vana-vigala
# Processing Record 15 of Set 5 | hami
# Processing Record 16 of Set 5 | kavaratti
# Processing Record 17 of Set 5 | necochea
# Processing Record 18 of Set 5 | benghazi
# Processing Record 19 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 5 | mehamn
# Processing Record 21 of Set 5 | la ronge
# Processing Record 22 of Set 5 | tillabery
# City not found. Skipping...
# Processing Record 23 of Set 5 | margate
# Processing Record 24 of Set 5 | iqaluit
# Processing Record 25 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | rio gallegos
# Processing Record 29 of Set 5 | grand-lahou
# Processing Record 30 of Set 5 | mataquescuintla
# Processing Record 31 of Set 5 | flinders
# Processing Record 32 of Set 5 | victoria
# Processing Record 33 of Set 5 | palmer
# Processing Record 34 of Set 5 | verkhnyaya khava
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | souillac
# Processing Record 37 of Set 5 | bayan
# Processing Record 38 of Set 5 | hirosaki
# Processing Record 39 of Set 5 | rosetta
# Processing Record 40 of Set 5 | vostok
# Processing Record 41 of Set 5 | bredasdorp
# Processing Record 42 of Set 5 | walvis bay
# Processing Record 43 of Set 5 | andapa
# Processing Record 44 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 5 | makakilo city
# Processing Record 46 of Set 5 | tuktoyaktuk
# Processing Record 47 of Set 5 | shenjiamen
# Processing Record 48 of Set 5 | ostrovnoy
# Processing Record 49 of Set 5 | pekan
# Processing Record 50 of Set 5 | hobyo
# Processing Record 1 of Set 6 | nova olinda do norte
# Processing Record 2 of Set 6 | krasnoselkup
# Processing Record 3 of Set 6 | vila velha
# Processing Record 4 of Set 6 | jalu
# Processing Record 5 of Set 6 | chute-aux-outardes
# Processing Record 6 of Set 6 | talnakh
# Processing Record 7 of Set 6 | santa cruz
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | saint-gaudens
# Processing Record 10 of Set 6 | manjacaze
# Processing Record 11 of Set 6 | maroantsetra
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | kitimat
# Processing Record 14 of Set 6 | mae hong son
# Processing Record 15 of Set 6 | tura
# Processing Record 16 of Set 6 | hirara
# Processing Record 17 of Set 6 | imeni poliny osipenko
# Processing Record 18 of Set 6 | broken hill
# Processing Record 19 of Set 6 | dunedin
# Processing Record 20 of Set 6 | puerto leguizamo
# Processing Record 21 of Set 6 | nikolskoye
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | bud
# Processing Record 24 of Set 6 | tuatapere
# Processing Record 25 of Set 6 | vysokaya gora
# Processing Record 26 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 6 | college
# Processing Record 28 of Set 6 | shingu
# Processing Record 29 of Set 6 | baraboo
# Processing Record 30 of Set 6 | upata
# Processing Record 31 of Set 6 | hastings
# Processing Record 32 of Set 6 | castro
# Processing Record 33 of Set 6 | sao joao da barra
# Processing Record 34 of Set 6 | goulburn
# Processing Record 35 of Set 6 | awjilah
# Processing Record 36 of Set 6 | port hardy
# Processing Record 37 of Set 6 | livadiya
# Processing Record 38 of Set 6 | coihaique
# Processing Record 39 of Set 6 | chara
# Processing Record 40 of Set 6 | krasnorechenskiy
# Processing Record 41 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 6 | maarianhamina
# Processing Record 43 of Set 6 | nanakuli
# Processing Record 44 of Set 6 | maragogi
# Processing Record 45 of Set 6 | tautira
# Processing Record 46 of Set 6 | eregli
# Processing Record 47 of Set 6 | daura
# Processing Record 48 of Set 6 | tupiza
# Processing Record 49 of Set 6 | trelew
# Processing Record 50 of Set 6 | turbat
# Processing Record 1 of Set 7 | bethel
# Processing Record 2 of Set 7 | chegdomyn
# Processing Record 3 of Set 7 | kajaani
# Processing Record 4 of Set 7 | qingyuan
# Processing Record 5 of Set 7 | brawley
# Processing Record 6 of Set 7 | sangar
# Processing Record 7 of Set 7 | tecoanapa
# Processing Record 8 of Set 7 | chilca
# Processing Record 9 of Set 7 | lesnoye
# Processing Record 10 of Set 7 | itarema
# Processing Record 11 of Set 7 | kars
# Processing Record 12 of Set 7 | cabedelo
# Processing Record 13 of Set 7 | monte alegre
# Processing Record 14 of Set 7 | codrington
# Processing Record 15 of Set 7 | vilhena
# Processing Record 16 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 7 | koraput
# Processing Record 18 of Set 7 | kurdzhinovo
# Processing Record 19 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 7 | le port
# Processing Record 21 of Set 7 | phan thiet
# Processing Record 22 of Set 7 | sibolga
# Processing Record 23 of Set 7 | nago
# Processing Record 24 of Set 7 | ihosy
# Processing Record 25 of Set 7 | totma
# Processing Record 26 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 7 | itacare
# Processing Record 28 of Set 7 | manokwari
# Processing Record 29 of Set 7 | klaksvik
# Processing Record 30 of Set 7 | kungurtug
# Processing Record 31 of Set 7 | kargasok
# Processing Record 32 of Set 7 | ayapel
# Processing Record 33 of Set 7 | garissa
# Processing Record 34 of Set 7 | contamana
# Processing Record 35 of Set 7 | beyneu
# Processing Record 36 of Set 7 | grand gaube
# Processing Record 37 of Set 7 | batagay-alyta
# Processing Record 38 of Set 7 | eureka
# Processing Record 39 of Set 7 | atbasar
# Processing Record 40 of Set 7 | neuquen
# Processing Record 41 of Set 7 | hay river
# Processing Record 42 of Set 7 | coquimbo
# Processing Record 43 of Set 7 | sabang
# Processing Record 44 of Set 7 | tessalit
# Processing Record 45 of Set 7 | radcliff
# Processing Record 46 of Set 7 | kenai
# Processing Record 47 of Set 7 | talara
# Processing Record 48 of Set 7 | lvov
# Processing Record 49 of Set 7 | hamilton
# Processing Record 50 of Set 7 | san carlos de bariloche
# Processing Record 1 of Set 8 | da nang
# Processing Record 2 of Set 8 | grindavik
# Processing Record 3 of Set 8 | cherskiy
# Processing Record 4 of Set 8 | sorland
# Processing Record 5 of Set 8 | lincoln
# Processing Record 6 of Set 8 | tono
# Processing Record 7 of Set 8 | the colony
# Processing Record 8 of Set 8 | machhlishahr
# Processing Record 9 of Set 8 | fort nelson
# Processing Record 10 of Set 8 | aleksandrovskiy zavod
# Processing Record 11 of Set 8 | prince rupert
# Processing Record 12 of Set 8 | damavand
# Processing Record 13 of Set 8 | mizusawa
# Processing Record 14 of Set 8 | buala
# Processing Record 15 of Set 8 | pryluky
# Processing Record 16 of Set 8 | praia
# Processing Record 17 of Set 8 | deming
# Processing Record 18 of Set 8 | yagodnoye
# Processing Record 19 of Set 8 | berbera
# Processing Record 20 of Set 8 | nizhniy odes
# Processing Record 21 of Set 8 | governador valadares
# Processing Record 22 of Set 8 | manono
# Processing Record 23 of Set 8 | staryy nadym
# Processing Record 24 of Set 8 | belaya gora
# Processing Record 25 of Set 8 | bathsheba
# Processing Record 26 of Set 8 | dolores
# Processing Record 27 of Set 8 | zvishavane
# Processing Record 28 of Set 8 | hambantota
# Processing Record 29 of Set 8 | methoni
# Processing Record 30 of Set 8 | oranjestad
# Processing Record 31 of Set 8 | jaen
# Processing Record 32 of Set 8 | santa cruz cabralia
# Processing Record 33 of Set 8 | cap-aux-meules
# Processing Record 34 of Set 8 | yumen
# Processing Record 35 of Set 8 | lakes entrance
# Processing Record 36 of Set 8 | boguchany
# Processing Record 37 of Set 8 | atar
# Processing Record 38 of Set 8 | amuntai
# Processing Record 39 of Set 8 | san patricio
# Processing Record 40 of Set 8 | nome
# Processing Record 41 of Set 8 | kachug
# Processing Record 42 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 43 of Set 8 | port elizabeth
# Processing Record 44 of Set 8 | ratnagiri
# Processing Record 45 of Set 8 | maldonado
# Processing Record 46 of Set 8 | gazli
# Processing Record 47 of Set 8 | frederico westphalen
# Processing Record 48 of Set 8 | broome
# Processing Record 49 of Set 8 | airai
# Processing Record 50 of Set 8 | tangier
# Processing Record 1 of Set 9 | machacamarca
# Processing Record 2 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 9 | akyab
# Processing Record 4 of Set 9 | balad
# Processing Record 5 of Set 9 | izhma
# Processing Record 6 of Set 9 | honavar
# Processing Record 7 of Set 9 | ampanihy
# Processing Record 8 of Set 9 | antofagasta
# Processing Record 9 of Set 9 | tres arroyos
# Processing Record 10 of Set 9 | russell
# Processing Record 11 of Set 9 | okha
# Processing Record 12 of Set 9 | thompson
# Processing Record 13 of Set 9 | ximei
# Processing Record 14 of Set 9 | vestmanna
# Processing Record 15 of Set 9 | henties bay
# Processing Record 16 of Set 9 | cabra
# Processing Record 17 of Set 9 | san cristobal
# Processing Record 18 of Set 9 | quirinopolis
# Processing Record 19 of Set 9 | rosarito
# Processing Record 20 of Set 9 | neyshabur
# Processing Record 21 of Set 9 | emporia
# Processing Record 22 of Set 9 | cerrito
# Processing Record 23 of Set 9 | burica
# City not found. Skipping...
# Processing Record 24 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 9 | masakin
# Processing Record 26 of Set 9 | arandelovac
# City not found. Skipping...
# Processing Record 27 of Set 9 | swan river
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | manado
# Processing Record 30 of Set 9 | vardo
# Processing Record 31 of Set 9 | mubende
# Processing Record 32 of Set 9 | bontang
# Processing Record 33 of Set 9 | meulaboh
# Processing Record 34 of Set 9 | sinop
# Processing Record 35 of Set 9 | vila
# Processing Record 36 of Set 9 | benguela
# Processing Record 37 of Set 9 | aklavik
# Processing Record 38 of Set 9 | port augusta
# Processing Record 39 of Set 9 | vernon
# Processing Record 40 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 9 | cravo norte
# Processing Record 42 of Set 9 | junqueiro
# Processing Record 43 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 9 | cururupu
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | chumikan
# Processing Record 47 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 9 | tuy hoa
# Processing Record 49 of Set 9 | lufilufi
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | jijiang
# Processing Record 2 of Set 10 | ixtapa
# Processing Record 3 of Set 10 | dicamay
# Processing Record 4 of Set 10 | xinqing
# Processing Record 5 of Set 10 | moree
# Processing Record 6 of Set 10 | bulgan
# Processing Record 7 of Set 10 | buraydah
# Processing Record 8 of Set 10 | salalah
# Processing Record 9 of Set 10 | gedo
# Processing Record 10 of Set 10 | bolobo
# Processing Record 11 of Set 10 | ilhabela
# Processing Record 12 of Set 10 | laguna
# Processing Record 13 of Set 10 | turukhansk
# Processing Record 14 of Set 10 | aliaga
# Processing Record 15 of Set 10 | ketchikan
# Processing Record 16 of Set 10 | katsuura
# Processing Record 17 of Set 10 | tarquinia
# Processing Record 18 of Set 10 | borovskoy
# Processing Record 19 of Set 10 | bintulu
# Processing Record 20 of Set 10 | lagoa
# Processing Record 21 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 10 | mareeba
# Processing Record 24 of Set 10 | ishigaki
# Processing Record 25 of Set 10 | diffa
# Processing Record 26 of Set 10 | ormond beach
# Processing Record 27 of Set 10 | baykit
# Processing Record 28 of Set 10 | qasigiannguit
# Processing Record 29 of Set 10 | conde
# Processing Record 30 of Set 10 | port moresby
# Processing Record 31 of Set 10 | millinocket
# Processing Record 32 of Set 10 | terrasini
# Processing Record 33 of Set 10 | omsukchan
# Processing Record 34 of Set 10 | khasan
# Processing Record 35 of Set 10 | ilulissat
# Processing Record 36 of Set 10 | otukpo
# Processing Record 37 of Set 10 | bartica
# Processing Record 38 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 10 | binghamton
# Processing Record 40 of Set 10 | mana
# Processing Record 41 of Set 10 | orichi
# Processing Record 42 of Set 10 | nabire
# Processing Record 43 of Set 10 | okato
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | fuerte olimpo
# Processing Record 46 of Set 10 | husavik
# Processing Record 47 of Set 10 | tocopilla
# Processing Record 48 of Set 10 | mersing
# Processing Record 49 of Set 10 | kuching
# Processing Record 50 of Set 10 | qandala
# Processing Record 1 of Set 11 | solano
# Processing Record 2 of Set 11 | hofn
# Processing Record 3 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 11 | wau
# Processing Record 5 of Set 11 | san quintin
# Processing Record 6 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 11 | lasa
# Processing Record 8 of Set 11 | sur
# Processing Record 9 of Set 11 | medvedka
# Processing Record 10 of Set 11 | jiujiang
# Processing Record 11 of Set 11 | novikovo
# Processing Record 12 of Set 11 | ranchpar
# Processing Record 13 of Set 11 | seoul
# Processing Record 14 of Set 11 | mayumba
# Processing Record 15 of Set 11 | luderitz
# Processing Record 16 of Set 11 | west bay
# Processing Record 17 of Set 11 | zhangye
# Processing Record 18 of Set 11 | marovoay
# Processing Record 19 of Set 11 | ryomgard
# Processing Record 20 of Set 11 | hirado
# Processing Record 21 of Set 11 | altus
# Processing Record 22 of Set 11 | chagoda
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | xuddur
# Processing Record 25 of Set 11 | coahuayana
# Processing Record 26 of Set 11 | bemidji
# Processing Record 27 of Set 11 | karla
# Processing Record 28 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 11 | shelburne
# Processing Record 30 of Set 11 | ust-nera
# Processing Record 31 of Set 11 | nizhneangarsk
# Processing Record 32 of Set 11 | beringovskiy
# Processing Record 33 of Set 11 | metro
# Processing Record 34 of Set 11 | bull savanna
# Processing Record 35 of Set 11 | aracaju
# Processing Record 36 of Set 11 | sayyan
# Processing Record 37 of Set 11 | shasta lake
# Processing Record 38 of Set 11 | kabul
# Processing Record 39 of Set 11 | labrea
# Processing Record 40 of Set 11 | lodja
# Processing Record 41 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 42 of Set 11 | nyagan
# Processing Record 43 of Set 11 | bengkulu
# Processing Record 44 of Set 11 | amurzet
# Processing Record 45 of Set 11 | bonthe
# Processing Record 46 of Set 11 | chenzhou
# Processing Record 47 of Set 11 | fayaoue
# Processing Record 48 of Set 11 | zajecar
# Processing Record 49 of Set 11 | nagato
# Processing Record 50 of Set 11 | yarensk
# Processing Record 1 of Set 12 | tashla
# Processing Record 2 of Set 12 | houma
# Processing Record 3 of Set 12 | mufulira
# Processing Record 4 of Set 12 | lompoc
# Processing Record 5 of Set 12 | patiya
# Processing Record 6 of Set 12 | novomykolayivka
# Processing Record 7 of Set 12 | pochutla
# Processing Record 8 of Set 12 | biak
# Processing Record 9 of Set 12 | bastia
# Processing Record 10 of Set 12 | pisco
# Processing Record 11 of Set 12 | richland
# Processing Record 12 of Set 12 | mahon
# Processing Record 13 of Set 12 | alberton
# Processing Record 14 of Set 12 | concordia
# Processing Record 15 of Set 12 | lixourion
# Processing Record 16 of Set 12 | northam
# Processing Record 17 of Set 12 | sakakah
# Processing Record 18 of Set 12 | suluq
# Processing Record 19 of Set 12 | sinegorye
# Processing Record 20 of Set 12 | sekoma
# Processing Record 21 of Set 12 | mecca
# Processing Record 22 of Set 12 | burhaniye
# Processing Record 23 of Set 12 | alibag
# Processing Record 24 of Set 12 | yabucoa
# Processing Record 25 of Set 12 | whitehorse
# Processing Record 26 of Set 12 | touros
# Processing Record 27 of Set 12 | dhidhdhoo
# Processing Record 28 of Set 12 | kavali
# Processing Record 29 of Set 12 | port blair
# Processing Record 30 of Set 12 | ulaangom
# Processing Record 31 of Set 12 | saint-pierre
# Processing Record 32 of Set 12 | beldanga
# Processing Record 33 of Set 12 | juneau
# Processing Record 34 of Set 12 | sarh
# Processing Record 35 of Set 12 | pimentel
# Processing Record 36 of Set 12 | port hedland
# Processing Record 37 of Set 12 | minatitlan
# Processing Record 38 of Set 12 | wairoa
# Processing Record 39 of Set 12 | oistins
# Processing Record 40 of Set 12 | torbat-e jam
# Processing Record 41 of Set 12 | cotonou
# Processing Record 42 of Set 12 | ust-maya
# Processing Record 43 of Set 12 | longjiang
# Processing Record 44 of Set 12 | bay city
# Processing Record 45 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 46 of Set 12 | leshukonskoye
# Processing Record 47 of Set 12 | santiago de cao
# Processing Record 48 of Set 12 | araouane
# Processing Record 49 of Set 12 | salamanca
# Processing Record 50 of Set 12 | asau
# Processing Record 1 of Set 13 | damaturu
# Processing Record 2 of Set 13 | kahului
# Processing Record 3 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 4 of Set 13 | yatou
# Processing Record 5 of Set 13 | potosi
# Processing Record 6 of Set 13 | cuamba
# Processing Record 7 of Set 13 | kyshtovka
# Processing Record 8 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 13 | hammerfest
# Processing Record 10 of Set 13 | kununurra
# Processing Record 11 of Set 13 | khandyga
# Processing Record 12 of Set 13 | baturaja
# Processing Record 13 of Set 13 | batemans bay
# Processing Record 14 of Set 13 | lapua
# Processing Record 15 of Set 13 | rabo de peixe
# Processing Record 16 of Set 13 | tual
# Processing Record 17 of Set 13 | kansanshi
# Processing Record 18 of Set 13 | tilichiki
# Processing Record 19 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 13 | dublin
# Processing Record 21 of Set 13 | kimbe
# Processing Record 22 of Set 13 | camana
# Processing Record 23 of Set 13 | bayonet point
# Processing Record 24 of Set 13 | san policarpo
# Processing Record 25 of Set 13 | roebourne
# Processing Record 26 of Set 13 | humaita
# Processing Record 27 of Set 13 | ebetsu
# Processing Record 28 of Set 13 | heide
# Processing Record 29 of Set 13 | olovyannaya
# Processing Record 30 of Set 13 | kamariotissa
# Processing Record 31 of Set 13 | qaqortoq
# Processing Record 32 of Set 13 | skjervoy
# Processing Record 33 of Set 13 | bilma
# Processing Record 34 of Set 13 | shimoda
# Processing Record 35 of Set 13 | praia da vitoria
# Processing Record 36 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 13 | comodoro rivadavia
# Processing Record 38 of Set 13 | wanxian
# Processing Record 39 of Set 13 | svarstad
# Processing Record 40 of Set 13 | kruisfontein
# Processing Record 41 of Set 13 | linxia
# Processing Record 42 of Set 13 | katihar
# Processing Record 43 of Set 13 | adrar
# Processing Record 44 of Set 13 | divnomorskoye
# Processing Record 45 of Set 13 | naron
# Processing Record 46 of Set 13 | swan hill
# Processing Record 47 of Set 13 | sukhumi
# Processing Record 48 of Set 13 | karratha
# Processing Record 49 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 50 of Set 13 | uyuni
# Processing Record 1 of Set 14 | staritsa
# Processing Record 2 of Set 14 | clyde river
# Processing Record 3 of Set 14 | dzhebariki-khaya
# Processing Record 4 of Set 14 | christchurch
# Processing Record 5 of Set 14 | shieli
# Processing Record 6 of Set 14 | yuancheng
# Processing Record 7 of Set 14 | nyrob
# Processing Record 8 of Set 14 | darnah
# Processing Record 9 of Set 14 | jiaojiang
# Processing Record 10 of Set 14 | melfort
# Processing Record 11 of Set 14 | sitka
# Processing Record 12 of Set 14 | mitsamiouli
# Processing Record 13 of Set 14 | cap-chat
# Processing Record 14 of Set 14 | srivardhan
# Processing Record 15 of Set 14 | saint charles
# Processing Record 16 of Set 14 | fairview
# Processing Record 17 of Set 14 | kirakira
# Processing Record 18 of Set 14 | gambela
# Processing Record 19 of Set 14 | chicama
# Processing Record 20 of Set 14 | lazaro cardenas
# Processing Record 21 of Set 14 | porto walter
# Processing Record 22 of Set 14 | faaborg
# Processing Record 23 of Set 14 | gambo
# Processing Record 24 of Set 14 | san juan
# Processing Record 25 of Set 14 | chanute
# Processing Record 26 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 14 | maniitsoq
# Processing Record 28 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 14 | carauari
# Processing Record 30 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 14 | leova
# Processing Record 32 of Set 14 | inhambane
# Processing Record 33 of Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 34 of Set 14 | sioux lookout
# Processing Record 35 of Set 14 | kuryk
# Processing Record 36 of Set 14 | kloulklubed
# Processing Record 37 of Set 14 | ca mau
# Processing Record 38 of Set 14 | kemang
# Processing Record 39 of Set 14 | cabcab
# Processing Record 40 of Set 14 | kresek
# Processing Record 41 of Set 14 | alta floresta
# Processing Record 42 of Set 14 | gushikawa
# Processing Record 43 of Set 14 | saiha
# Processing Record 44 of Set 14 | toungoo
# City not found. Skipping...
# Processing Record 45 of Set 14 | taksimo
# Processing Record 46 of Set 14 | samarai
# Processing Record 47 of Set 14 | pocinhos
# Processing Record 48 of Set 14 | kautokeino
# Processing Record 49 of Set 14 | de aar
# Processing Record 50 of Set 14 | turayf
# Processing Record 1 of Set 15 | noumea
# Processing Record 2 of Set 15 | balkanabat
# Processing Record 3 of Set 15 | ende
# Processing Record 4 of Set 15 | kjollefjord
# Processing Record 5 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 15 | kayerkan
# Processing Record 7 of Set 15 | rundu
# Processing Record 8 of Set 15 | nurota
# Processing Record 9 of Set 15 | vanimo
# Processing Record 10 of Set 15 | luena
# Processing Record 11 of Set 15 | scarborough
# Processing Record 12 of Set 15 | bushehr
# Processing Record 13 of Set 15 | lata
# Processing Record 14 of Set 15 | dawei
# Processing Record 15 of Set 15 | balclutha
# Processing Record 16 of Set 15 | haapsalu
# Processing Record 17 of Set 15 | noboribetsu
# Processing Record 18 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 15 | koyelga
# Processing Record 20 of Set 15 | severodvinsk
# Processing Record 21 of Set 15 | alamogordo
# Processing Record 22 of Set 15 | ahuimanu
# Processing Record 23 of Set 15 | sembe
# Processing Record 24 of Set 15 | irbeyskoye
# Processing Record 25 of Set 15 | saint augustine
# Processing Record 26 of Set 15 | vaitape
# Processing Record 27 of Set 15 | mulchen
# Processing Record 28 of Set 15 | sayville
# Processing Record 29 of Set 15 | preobrazheniye
# Processing Record 30 of Set 15 | anchorage
# Processing Record 31 of Set 15 | podgornoye
# Processing Record 32 of Set 15 | redwood city
# Processing Record 33 of Set 15 | arcos
# Processing Record 34 of Set 15 | katwa
# Processing Record 35 of Set 15 | honiara
# Processing Record 36 of Set 15 | najibabad
# Processing Record 37 of Set 15 | pacific grove
# Processing Record 38 of Set 15 | mastic beach
# Processing Record 39 of Set 15 | angoche
# Processing Record 40 of Set 15 | tarakan
# Processing Record 41 of Set 15 | jining
# Processing Record 42 of Set 15 | mundo nuevo
# Processing Record 43 of Set 15 | forio
# Processing Record 44 of Set 15 | toging
# City not found. Skipping...
# Processing Record 45 of Set 15 | siavonga
# Processing Record 46 of Set 15 | nishihara
# Processing Record 47 of Set 15 | bereznik
# Processing Record 48 of Set 15 | dvinskoy
# Processing Record 49 of Set 15 | kisangani
# Processing Record 50 of Set 15 | ginda
# Processing Record 1 of Set 16 | warri
# Processing Record 2 of Set 16 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 16 | curvelo
# Processing Record 4 of Set 16 | leku
# Processing Record 5 of Set 16 | talaya
# Processing Record 6 of Set 16 | we
# City not found. Skipping...
# Processing Record 7 of Set 16 | sparta
# Processing Record 8 of Set 16 | pietersburg
# Processing Record 9 of Set 16 | gamba
# Processing Record 10 of Set 16 | altamont
# Processing Record 11 of Set 16 | namatanai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0            Bambous Virieux -20.3428   57.7575     71.22        68
# 1                     Padang  -0.9492  100.3543     77.85        86
# 2                 Butaritari   3.0707  172.7902     82.62        70
# 3                     Kiunga  -6.1219  141.2906     72.97        99
# 4                    Kearney  40.6995  -99.0815     64.49        38
# 5                     Albany  42.6001  -73.9662     72.03        68
# 6  San Bartolome De Tirajana  27.9248  -15.5733     68.32        62
# 7                   Vallenar -28.5708  -70.7581     67.69        35
# 8                Constantine  36.3650    6.6147     84.02        35
# 9                 Hervey Bay -25.2986  152.8535     55.04        45
#
#    Cloudiness  Wind Speed Country Current Description
# 0          38       14.14      MU    scattered clouds
# 1          98        4.25      ID          light rain
# 2          92       16.75      KI     overcast clouds
# 3         100        2.80      PG       moderate rain
# 4          49       13.44      US    scattered clouds
# 5         100        9.46      US     overcast clouds
# 6           6        8.84      ES           clear sky
# 7          64        6.24      CL       broken clouds
# 8          47        4.36      DZ    scattered clouds
# 9           0       17.31      AU           clear sky

# %%
#reorder our columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Bambous Virieux      MU -20.3428   57.7575     71.22        68
# 1             Padang      ID  -0.9492  100.3543     77.85        86
# 2         Butaritari      KI   3.0707  172.7902     82.62        70
# 3             Kiunga      PG  -6.1219  141.2906     72.97        99
# 4            Kearney      US  40.6995  -99.0815     64.49        38
# ..               ...     ...      ...       ...       ...       ...
# 694           Sparta      US  43.9441  -90.8129     65.97        71
# 695      Pietersburg      ZA -23.9045   29.4688     58.84        72
# 696            Gamba      GA  -2.6500   10.0000     76.44        79
# 697         Altamont      US  42.2068 -121.7372     59.77        61
# 698        Namatanai      PG  -3.6667  152.4333     77.92        84
#
#      Cloudiness  Wind Speed Current Description
# 0            38       14.14    scattered clouds
# 1            98        4.25          light rain
# 2            92       16.75     overcast clouds
# 3           100        2.80       moderate rain
# 4            49       13.44    scattered clouds
# ..          ...         ...                 ...
# 694          14       13.40          few clouds
# 695           2       20.65           clear sky
# 696          99        8.19     overcast clouds
# 697           0        1.01           clear sky
# 698         100        3.20          light rain
#
# [699 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
